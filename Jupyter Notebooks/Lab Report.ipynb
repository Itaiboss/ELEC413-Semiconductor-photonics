# %%
import numpy as np

import scipy.io
f = scipy.io.loadmat('PVI.mat')

# Extract the structured array
Isweep = f["Isweep"]

# Extract individual NumPy arrays
V = np.array(Isweep["V"][0, 0][0])
I = np.array(Isweep["I"][0, 0][0])
P = np.array(Isweep["P"][0, 0][0])
Iset = np.array(Isweep["Iset"][0, 0][0])
print(V)
# Out:
# [0.975166 0.97571  0.976256 0.976778 0.977408 0.977923 0.978436 0.97904
#  0.979548 0.980044 0.980648 0.981149 0.981628 0.982213 0.9827   0.983169
#  0.983649 0.984212 0.984689 0.985151 0.985707 0.986165 0.986611 0.987114
#  0.987453 0.987736 0.988036 0.988265 0.988496 0.988732 0.989006 0.989236
#  0.989468 0.989741 0.989962 0.990177 0.990461 0.990681 0.990913 0.991174
#  0.991401 0.991632 0.99185  0.992129 0.99236  0.992568 0.992845 0.993062
#  0.993294 0.993556]
