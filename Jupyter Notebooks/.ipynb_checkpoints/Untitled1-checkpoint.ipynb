# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

csv_file = 'SwingQ.csv'  
data = pd.read_csv(csv_file)


print(data.head())
sps = len(acceleration_data)/128.45

acceleration_data = data['Absolute acceleration (m/s^2)']
N = len(acceleration_data)
t = data['Time (s)']

acceleration_data = acceleration_data-9.81
max_value = np.max(acceleration_data)
e_value = max_value * 1/np.e
#avg t for 1/e = 76s 
t_1e = 76
fn =1/1.76 (measured average period)
plt.figure(figsize=(10, 6))
plt.plot(t,acceleration_data, label='Absolute Acceleration')

plt.axhline(y=max_value, color='red', linestyle='--', label=f'Max Value = {max_value:.2f}')
plt.axhline(y=e_value, color='green', linestyle='--', label=f'1/e Value = {half_max_value:.2f}')

Q=(1/1.7)/(1/t_1e)
print(Q)

plt.xlabel('Time (s)')
plt.ylabel('Absolute Acceleration (m/s²)')
plt.title('Absolute Acceleration Data from E2-E12806')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#    Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0  0.004735               -2.162553                2.240541
# 1  0.014766               -2.173331                2.019151
# 2  0.024797               -1.990710                1.688339
# 3  0.034828               -1.416355                1.681753
# 4  0.044859               -1.227148                1.505719
#
#    Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# 0                7.079528                       7.734105
# 1                7.105125                       7.699554
# 2                7.110065                       7.574063
# 3                7.553742                       7.867234
# 4                8.779543                       8.991855
# 13.704747864672115
# 44.70588235294118

# %% [markdown]
# $Q=\frac{\tau*2\pi*f_n}{2}$ where tau is the time to decay to 1/e, $f_n=1/Tn$ (oscillation frequency)

# %%
Q=t_1e*np.pi*fn/2
print(Q)
# Out:
# 67.82984138432508
